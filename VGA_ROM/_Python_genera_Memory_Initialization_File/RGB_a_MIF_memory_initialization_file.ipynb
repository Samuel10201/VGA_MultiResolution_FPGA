# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
dirpath = os.getcwd()
print("current directory is : " + dirpath)
foldername = os.path.basename(dirpath)
print("Directory name is : " + foldername)
# Aquí debe indicar la ubicación de sus archivos
os.chdir("/content/drive/MyDrive/Estructura_del_Computador/Procesamiento_Imagen")
dirpath = os.getcwd()
print("current directory is : " + dirpath)
foldername = os.path.basename(dirpath)
print("Directory name is : " + foldername)
# Out:
# current directory is : /content
# Directory name is : content
# current directory is : /content/drive/MyDrive/Estructura_del_Computador/Procesamiento_Imagen
# Directory name is : Procesamiento_Imagen

# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen = imageio.imread(os.path.join(dirpath,'Eduardo_Zurek_ejemplo.jpg'))
im0 = Image.fromarray(imagen)
im0 = im0.resize((128,128)) #, Image.ANTIALIAS)
imagen = np.asarray(im0,'uint8')
im1 = Image.fromarray(imagen)
im1 = im1.save("EZ_128.bmp")
# Out:
# <ipython-input-4-152720971a69>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   imagen = imageio.imread(os.path.join(dirpath,'Eduardo_Zurek_ejemplo.jpg'))

# %%
print(imagen.shape)
red = imagen[:,:,0].flatten()
print(red.shape)
green = imagen[:,:,1].flatten()
print(green.shape)
blue = imagen[:,:,2].flatten()
print(blue.shape)
# Out:
# (128, 128, 3)
# (16384,)
# (16384,)
# (16384,)

# %%
azul = np.uint8(blue)
verde = np.uint8(green)
rojo = np.uint8(red)
representacion = np.uint16(rojo+verde+azul)

# %%
print(bin(azul[0]))
print(len(azul))
for i in range(20):
  print([format(rojo[i],'02x')+format(verde[i],'02x')+format(azul[i],'02x'),hex(rojo[i]),bin(rojo[i]),hex(verde[i]),bin(verde[i]),hex(azul[i]),bin(azul[i])])
# Out:
# 0b1100
# 16384
# ['66910c', '0x66', '0b1100110', '0x91', '0b10010001', '0xc', '0b1100']
# ['5f8e08', '0x5f', '0b1011111', '0x8e', '0b10001110', '0x8', '0b1000']
# ['628c02', '0x62', '0b1100010', '0x8c', '0b10001100', '0x2', '0b10']
# ['648f02', '0x64', '0b1100100', '0x8f', '0b10001111', '0x2', '0b10']
# ['669406', '0x66', '0b1100110', '0x94', '0b10010100', '0x6', '0b110']
# ['618f03', '0x61', '0b1100001', '0x8f', '0b10001111', '0x3', '0b11']
# ['628e03', '0x62', '0b1100010', '0x8e', '0b10001110', '0x3', '0b11']
# ['5a8e0d', '0x5a', '0b1011010', '0x8e', '0b10001110', '0xd', '0b1101']
# ['378521', '0x37', '0b110111', '0x85', '0b10000101', '0x21', '0b100001']
# ['398e2b', '0x39', '0b111001', '0x8e', '0b10001110', '0x2b', '0b101011']
# ['50911d', '0x50', '0b1010000', '0x91', '0b10010001', '0x1d', '0b11101']
# ['5a8720', '0x5a', '0b1011010', '0x87', '0b10000111', '0x20', '0b100000']
# ['c1ab38', '0xc1', '0b11000001', '0xab', '0b10101011', '0x38', '0b111000']
# ...

# %%
# prompt: escribe un programa en python que genere un archivo memory initialization file (.mif) de datos aleatorios con los siguientes parámetros:
# DEPTH = 32768
# WIDTH = 24
# ADDRESS_RADIX = HEX
# DATA_RADIX = HEX

import random

def generate_mif_file(depth, width, filename="memory_init_128.mif"):
    """Generates a .mif file with random data."""

    with open(filename, "w") as f:
        f.write("DEPTH = " + str(depth) + ";\n")
        f.write("WIDTH = " + str(width) + ";\n")
        f.write("ADDRESS_RADIX = HEX;\n")
        f.write("DATA_RADIX = HEX;\n")
        f.write("CONTENT BEGIN\n")

        for i in range(depth):
            hex_data = format(rojo[i],'02x')+format(verde[i],'02x')+format(azul[i],'02x') #hex(random.randint(0, (1 << width) - 1))[2:].zfill(int(width / 4))
            f.write(f"{i:05X} : {hex_data};\n")

        f.write("END;\n")

# Example usage:
generate_mif_file(16384, 24)  # Creates memory_init.mif with default name
